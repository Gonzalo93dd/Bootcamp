# %% [markdown]
# # 1. Definir la contraseña correcta
# def pedir_contraseña():
#     contraseña_correcta = "gamer123"
#     ingreso = input("Ingresá la contraseña para empezar: ")
#     return ingreso == contraseña_correcta
#
# # 2. Definir palabra a encontrar
# def definir_palabra_a_encontrar():
#     return "python"
#
# # 3. Definir cantidad de letras
# def definir_cantidad_de_letras(palabra):
#     return len(palabra)
#
# # 4. Definir intentos
# def definir_intentos():
#     return 6
#
# # 5. Crear grilla vacía
# def crear_grilla_vacia(palabra):
#     return ["_" for _ in palabra]
#
# # 6. Mostrar mensaje de bienvenida
# def mostrar_mensaje_bienvenida(palabra, intentos, grilla):
#     print("¡Bienvenido al juego de adivinar la palabra!")
#     print(f"La palabra tiene {len(palabra)} letras.")
#     print(f"Tienes {intentos} intentos.")
#     print(" ".join(grilla))
#
# # 7. Pedir letra al jugador
# def pedir_letra():
#     letra = input("Ingresa una letra: ").lower()
#     return letra
#
# # 8. Actualizar la grilla si acierta
# def actualizar_grilla(letra, palabra, grilla):
#     acierto = False
#     for i in range(len(palabra)):
#         if palabra[i] == letra:
#             grilla[i] = letra
#             acierto = True
#     return acierto
#
# # 9. Mostrar progreso
# def mostrar_grilla(grilla):
#     print("Progreso:", " ".join(grilla))
#
# # 10. Juego principal
# def juego():
#     if not pedir_contraseña():
#         print("Contraseña incorrecta. Acceso denegado.")
#         return  # Sale del juego
#
#     palabra = definir_palabra_a_encontrar()
#     intentos = definir_intentos()
#     grilla = crear_grilla_vacia(palabra)
#
#     mostrar_mensaje_bienvenida(palabra, intentos, grilla)
#
#     while intentos > 0 and "_" in grilla:
#         letra = pedir_letra()
#         if actualizar_grilla(letra, palabra, grilla):
#             print("¡Bien! La letra está en la palabra.")
#         else:
#             print("Incorrecto. Esa letra no está.")
#             intentos -= 1
#         mostrar_grilla(grilla)
#         print(f"Intentos restantes: {intentos}")
#
#     if "_" not in grilla:
#         print("¡Felicidades! Adivinaste la palabra.")
#     else:
#         print(f"Perdiste. La palabra era: {palabra}")
#
# # Iniciar el juego
# juego()

# %%
########TERMINADO##############
def pedir_contraseña():
    contraseña_correcta = "hola"
    ingreso = input("ingrese la contraseña para empezar: ")
    return ingreso == contraseña_correcta

def definir_palabra_a_encontrar():
    return "gonza"

def definir_cantidad_de_letras(palabra):
    return len(palabra)

def definir_intentos():
    return 4

def crear_grilla_vacia(palabra):
    return ["_" for _ in palabra]

def mostrar_mensaje_bienvenida(palabra, intentos, grilla):
    print("Bienvenido al juego de la muerte,el nombre o codigo se familiariza al creador y deberas ingresar por letra")
    print(f"La palabra tiene {len(palabra)} letras.")
    print(f"Tienes {intentos} intentos.")
    print(" ".join(grilla))
    
def pedir_letra():
    letra = input("Ingresa una letra: ").lower()
    return letra

def actualizar_grilla(letra, palabra, grilla):
    acierto = False
    for i in range(len(palabra)):
        if palabra[i] == letra:
            grilla[i] = letra
            acierto = True
    return acierto

def mostrar_grilla(grilla):
    print("Progreso:", " ".join(grilla))
    
def juego():
    if not pedir_contraseña():
        print("Contraseña incorrecta, acceso denegado.")
        return

    palabra = definir_palabra_a_encontrar()
    intentos = definir_intentos()
    grilla = crear_grilla_vacia(palabra)

    mostrar_mensaje_bienvenida(palabra, intentos, grilla)

    while intentos > 0 and "_" in grilla:
        letra = pedir_letra()
        if actualizar_grilla(letra, palabra, grilla):
            print("¡Bien hecho!")
        else:
            print("Incorrecto. Esa letra no es, puto/a.")
            intentos -= 1
        mostrar_grilla(grilla)
        print(f"Intentos restantes: {intentos}")
        
    if "_" not in grilla:
        print("ganaste noche de alcohol")
    else:
        print(f"Perdiste, derecho a Tacumbú. La palabra era: {palabra}")
        
juego()

# %%
#INTENTO 1
def pedir_contresaña():
    contraseña_correcta =  "terere"
    ingreso = input("ingrese la contraseña para empezar: ")
    return ingreso == contraseña_correcta
    
def definir_palabra_a_encontrar():
    return "cielo"

def  definir_cantidad_de_letras(palabra):
    return len(palabra)

def definir_intentos ():
    return 3

def crear_grilla_vacia(palabra):
    return ["_" for _ in palabra]

def mostrar_mensaje_bienvenida(palabra, intentos, grilla):
    print("bienvenido al juego de la muerte jijij")
    print(f"la palabra tiene{len(palabra)} letras.")
    print(f"tienes {intentos} intentos.")
    print(" " .join(grilla))
    
def pedir_letra():
    letra = input("ingresa una letra: ").lower()
    return letra

def actualizar_grilla(letra, palabra, grilla):
    acierto = False
    for i in range(len(palabra)):
        if palabra[i] == letra: 
           grilla[i] = letra
           acierto = True
    return acierto

def mostra_grilla(grilla):
    print("progreso:", " ".join(grilla))
    
def juego():
    if not pedir_contresaña():
        print("contraseña incorrecta, acceso denegado.")
        return
    
    palabra = definir_palabra_a_encontrar()
    intentos = definir_intentos()
    grilla = crear_grilla_vacia(palabra)
    
    mostrar_mensaje_bienvenida(palabra, intentos, grilla)
    
    while intentos > 0 and "_" in grilla:
        letra = pedir_letra()
        if actualizar_grilla(letra, palabra, grilla):
            print("bien cerca pero aun no.")
        else:
            print("incorrecto. esa letra no es puto/a.")
            intentos -= 1 
        mostra_grilla(grilla)
        print(f"intentos restantes: {intentos}")
        
    if "_" not in grilla:
        print("GANASTE!!")
    else:
        print(f"perdiste, derecho a tacumbu. la palabra es: {palabra}")
        
juego()
# Out:
# bienvenido al juego de la muerte jijij
# la palabra tiene5 letras.
# tienes 3 intentos.
# _ _ _ _ _
# incorrecto. esa letra no es puto/a.
# progreso: _ _ _ _ _
# intentos restantes: 2
# incorrecto. esa letra no es puto/a.
# progreso: _ _ _ _ _
# intentos restantes: 1
# incorrecto. esa letra no es puto/a.
# progreso: _ _ _ _ _
# intentos restantes: 0
# perdiste, derecho a tacumbu. la palabra es: cielo

# %%
libro_de_lafortuna = [[2 for _ in range(4)] for _ in range(4)]
print(grilla)

for _ in range(8):
    print("hola")
# Out:
# [[2, 2, 2, 2], [2, 2, 2, 2], [2, 2, 2, 2], [2, 2, 2, 2]]
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
